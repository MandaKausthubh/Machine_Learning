# %%
# Importing the necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# Creating Linearly Seprable Data

# Initialising data
X_Val = np.linspace(start=-20, stop=20, num=100)
# Target function: y = -2x + 8
Y_Val = np.zeros_like(X_Val)

# Creating Scatter points
x = np.random.randint(low=-20, high=20, size=50)
y = np.random.randint(low=-20, high=20, size=50)

plt.scatter(x,y)
plt.show()
